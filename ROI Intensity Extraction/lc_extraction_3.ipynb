# %% [markdown]
# <h1 style="text-align: center;"> LOCUS COERULEUS (LC) - MEAN INTENSITY EXTRACTION </h1>

# %% [markdown]
# This notebook continues extraction for some of the participants missed during first extraction, due to server crash.

# %%
import os
import pandas as pd
import subprocess

# %%
# defining base directory and LC mask names
base_dir = "/hus/home/oliwin/data/study_name"

LC_mask = f"{base_dir}/LC_mask.nii.gz"
mask_lc_l = f"{base_dir}/LC_L_mask.nii.gz"
mask_lc_r = f"{base_dir}/LC_R_mask.nii.gz"

# %%
# 3rd list of missing participants
# this list contains 12 of the missing participants from the first extraction
missing_patients = ["00005DD2", "000063C4", "00006431", "000074E5", "0000763C", 
 "000077F0", "00007CE3", "00007E13", "0000811E", "000084C8", 
 "0000868E", "00008891"]

# dictionary to store participant-wise data
patients_data = {}

# defining missing list nr 3
output_file = 'mri_data_LC_missing_patients_3.csv'

header = ['Patient Number']
all_keys = set()

# saving current results to csv
def save_progress():
    global header

    all_keys.update(*(intensities.keys() for intensities in patients_data.values()))
    header = ['Patient Number'] + sorted(all_keys)

    output_data = []
    for patient_number, intensities in patients_data.items():
        row = [patient_number]
        for col in header[1:]:
            row.append(intensities.get(col, None))  # use None for missing values
        output_data.append(row)

    output_df = pd.DataFrame(output_data, columns=header)
    output_df.to_csv(output_file, index=False)
    print(f"Progress saved to {output_file}")


try:
    # loop through subdirectories 'FSL' in base_dir (recursively)
    for root, dirs, files in os.walk(base_dir):
        if "FSL" in dirs:
            fsl_dir = os.path.join(root, "FSL")
            
            # extracting participant number from folder name
            patient_number = os.path.basename(root)

            # processing only the specified missing participants
            if patient_number not in missing_patients:
                continue

            # loop through NIfTI files in FSL directory
            for filename in os.listdir(fsl_dir):
                # Process only files with "mni", "nii.gz"
                if (
                    "mni" in filename
                    and "mask" not in filename
                    and "new" not in filename
                    and "flirt" not in filename
                    and "flirt_masked" not in filename
                    and not filename.endswith(".mat")
                    and filename.endswith(".nii.gz")
                ):
                    input_file = os.path.join(fsl_dir, filename)

                    print(f"Processing file: {input_file}")

                    # loop through the LC masks (left, right, combined) - each MRI file is processed three times
                    for mask_file in [LC_mask, mask_lc_r, mask_lc_l]:
                        try:
                            # use FLIRT to perform registration of the LC masks
                            flirt_output = f"{input_file}_flirt_{os.path.basename(mask_file).split('.')[0]}"
                            flirt_matrix = f"{flirt_output}.mat"
                            flirt_command = f"flirt -in {input_file} -ref {mask_file} -out {flirt_output} -omat {flirt_matrix}"
                            process_flirt = subprocess.run(flirt_command, shell=True, capture_output=True, text=True)

                            if process_flirt.returncode != 0:
                                print(f"Error applying FLIRT to {filename} with mask {mask_file}: {process_flirt.stderr}")
                                continue  # continue with the next mask for same file

                            # use fslmaths to apply the masks and threshold negative values to zero
                            flirt_masked = f"{flirt_output}_masked"
                            fslmaths_command = f"fslmaths {flirt_output} -mas {mask_file} -thr 0 {flirt_masked}"
                            process_fslmaths = subprocess.run(fslmaths_command, shell=True, capture_output=True, text=True)

                            if process_fslmaths.returncode != 0:
                                print(f"Error applying fslmaths to {filename} with mask {mask_file}: {process_fslmaths.stderr}")
                                continue  # continue with the next mask for same file

                            # use fslstats to extract mean intensity within the region
                            stats_command = f"fslstats {flirt_masked} -M"  # -M for Mean Intensity
                            process_stats = subprocess.run(stats_command, shell=True, capture_output=True, text=True)

                            if process_stats.returncode != 0:
                                print(f"Error processing {filename}: {process_stats.stderr}")
                                continue  # continue with the next mask for same file

                            
                            stats = process_stats.stdout.strip().split()
                            mean_intensity = float(stats[0]) 

                            # remove intermediate files and temporary NIfTI outputs
                            try:
                                for file_to_delete in [flirt_matrix, flirt_output + ".nii.gz", flirt_masked + ".nii.gz"]:
                                    if os.path.exists(file_to_delete):
                                        os.remove(file_to_delete)
                                    else:
                                        print(f"File not found: {file_to_delete}")
                            except OSError as e:
                                print(f"Error deleting files for {filename}: {e}")

                            # add the data to the participant's entry
                            if patient_number not in patients_data:
                                patients_data[patient_number] = {}

                            mask_name = os.path.basename(mask_file).split('.')[0]  
                            filename_base = filename.replace('.nii.gz', '')
                            mask_key = f'{mask_name}_{filename_base}'

                            patients_data[patient_number][mask_key] = mean_intensity

                            # saving mean intensity immediately after each file is processed with all three masks
                            save_progress()

                        except Exception as e:
                            print(f"Error processing {filename} with mask {mask_file} for patient {patient_number}: {e}")
                            continue  # continue to the next mask or next file

    # final save after all participants and files have been processed
    print("Final saving progress...")
    save_progress()

# handle interruptions and unexpected errors
except KeyboardInterrupt:
    print("Process interrupted, saving progress...")
    save_progress()

except Exception as e:
    print(f"An error occurred: {e}")
    save_progress()
# Out:
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007E13/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00007CE3/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00005DD2/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/00008891/FSL/STAGE_simGM_reg_mni.nii.gz
# ...
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/000074E5/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Progress saved to mri_data_LC_missing_patients_3.csv
# Final saving progress...
# Progress saved to mri_data_LC_missing_patients_3.csv
