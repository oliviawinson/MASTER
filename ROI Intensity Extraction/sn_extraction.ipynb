# %% [markdown]
# <h1 style="text-align: center;"> SUBSTANTIA NIGRA (SN) - MEAN INTENSITY EXTRACTION </h1>

# %% [markdown]
# The following code was used to extract mean signal intensities in SNpc (left, right and both hemispheres)

# %%
import os
import pandas as pd
import subprocess

# %%
#defining base directory and SNpc mask names
base_dir = "/hus/home/oliwin/data/study_name"
mask_sn_l = f"{base_dir}/SN_L_mask.nii.gz"
mask_sn_r = f"{base_dir}/SN_R_mask.nii.gz"
SN_mask = f"{base_dir}/SN_mask.nii.gz"

# Fusing left and right hemispheres of SN
# !fslmaths {mask_sn_l} -add {mask_sn_r} {SN_mask}

# %%
# dictionary to store participant-wise data
patients_data = {}

# loop through subdirectories 'FSL' in base_dir (recursively)
for root, dirs, files in os.walk(base_dir):
    if "FSL" in dirs:
        fsl_dir = os.path.join(root, "FSL")
        
        # extract participant number from the folder name
        patient_number = os.path.basename(root)
        
        # loop through NIfTI files in FSL directory
        for filename in os.listdir(fsl_dir):
            # process files with "mni", "nii.gz"
            if (
                "mni" in filename
                and "mask" not in filename
                and "new" not in filename
                and "flirt" not in filename
                and "flirt_masked" not in filename
                and not filename.endswith(".mat")
                and filename.endswith(".nii.gz")
            ):
                input_file = os.path.join(fsl_dir, filename)

                
                print(f"Processing file: {input_file}")

                # loop through the SNpc masks (left, right and combined) - each MRI file is processed three times
                for mask_file in [SN_mask, mask_sn_r, mask_sn_l]:
                    try:
                        # use FLIRT to perform the registration of SNpc masks
                        flirt_output = f"{input_file}_flirt_{os.path.basename(mask_file).split('.')[0]}"
                        flirt_matrix = f"{flirt_output}.mat"
                        flirt_command = f"flirt -in {input_file} -ref {mask_file} -out {flirt_output} -omat {flirt_matrix}"
                        process_flirt = subprocess.run(flirt_command, shell=True, capture_output=True, text=True)

                        if process_flirt.returncode != 0:
                            print(f"Error applying FLIRT to {filename} with mask {mask_file}: {process_flirt.stderr}")
                            continue  # continue with the next mask for the same file

                        # use fslmaths to apply the masks and threshold negative values to zero
                        flirt_masked = f"{flirt_output}_masked"
                        fslmaths_command = f"fslmaths {flirt_output} -mas {mask_file} -thr 0 {flirt_masked}"
                        process_fslmaths = subprocess.run(fslmaths_command, shell=True, capture_output=True, text=True)

                        if process_fslmaths.returncode != 0:
                            print(f"Error applying fslmaths to {filename} with mask {mask_file}: {process_fslmaths.stderr}")
                            continue  # continue with the next mask for the same file

                        # use fslstats to extract mean intensity within the region
                        stats_command = f"fslstats {flirt_masked} -M"  # -M for Mean Intensity 
                        process_stats = subprocess.run(stats_command, shell=True, capture_output=True, text=True)

                        if process_stats.returncode != 0:
                            print(f"Error processing {filename}: {process_stats.stderr}")
                            continue  # continue with the next mask for the same file

                        
                        stats = process_stats.stdout.strip().split()
                        mean_intensity = float(stats[0]) 

                        # remove intermediate files and temporary NIfTI outputs
                        try:
                            for file_to_delete in [flirt_matrix, flirt_output + ".nii.gz", flirt_masked + ".nii.gz"]:
                                if os.path.exists(file_to_delete):
                                    os.remove(file_to_delete)
                                else:
                                    print(f"File not found: {file_to_delete}")
                        except OSError as e:
                            print(f"Error deleting files for {filename}: {e}")

                        # add the data to participant's entry
                        if patient_number not in patients_data:
                            patients_data[patient_number] = {}

                        mask_name = os.path.basename(mask_file).split('.')[0]  
                        filename_base = filename.replace('.nii.gz', '')  
                        mask_key = f'{mask_name}_{filename_base}'

                        patients_data[patient_number][mask_key] = mean_intensity

                    except Exception as e:
                        print(f"Error processing {filename} with mask {mask_file} for patient {patient_number}: {e}")
                        continue  # continue to the next mask or next file

# preparing the dataframe to store mean intensities
header = ['Patient Number']
all_keys = set()
for intensities in patients_data.values():
    all_keys.update(intensities.keys())
header.extend(sorted(all_keys))  

output_data = []
for patient_number, intensities in patients_data.items():
    row = [patient_number]
    for col in header[1:]:
        row.append(intensities.get(col, None))  # use None for missing values
    output_data.append(row)

# creating the dataframe
output_df = pd.DataFrame(output_data, columns=header)

# saving the dataframe as csv for further analysis
output_file = 'mri_data_sn.csv'  
output_df.to_csv(output_file, index=False)
print(f"Transformed CSV saved to {output_file}")
# Out:
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D71C/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000D2D0/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000997A/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008904/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00008289/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00005316/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002530/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000437C/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000096EB/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000077F0/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000040B3/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00003E5B/FSL/STAGE_simGM_reg_mni.nii.gz
# ...
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simCSF_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 160125 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_simCSF_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simCSF_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 160260 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_simCSF_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simCSF_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 160396 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Error applying fslmaths to STAGE_simFLAIR_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simFLAIR_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 160531 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_simFLAIR_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simFLAIR_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 160680 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_simFLAIR_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simFLAIR_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 160837 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simGM_reg_mni.nii.gz
# Error applying fslmaths to STAGE_simGM_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simGM_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 160916 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_simGM_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simGM_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161001 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_simGM_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simGM_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161080 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simWM_reg_mni.nii.gz
# Error applying fslmaths to STAGE_simWM_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simWM_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161169 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_simWM_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simWM_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161245 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_simWM_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simWM_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161321 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Error applying fslmaths to STAGE_sim_GRE_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GRE_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161401 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_sim_GRE_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GRE_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161489 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_sim_GRE_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GRE_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161572 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Error applying fslmaths to STAGE_sim_GREa_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GREa_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161655 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_sim_GREa_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GREa_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 161816 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_sim_GREa_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GREa_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 162001 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Error applying fslmaths to STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 162122 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 162296 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 162443 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Error applying fslmaths to STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 162634 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 162758 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 162841 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Error applying fslmaths to STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 162927 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_R_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_R_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 163001 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Error applying fslmaths to STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz with mask /hus/home/oliwin/data/study_name/SN_L_mask.nii.gz: terminate called after throwing an instance of 'std::filesystem::__cxx11::filesystem_error'
#   what():  filesystem error: status: Permission denied [/hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz_flirt_SN_L_mask.nii.gz]
# /usr/local/fsl/share/fsl/bin/fslmaths: line 2: 163082 Aborted                 (core dumped) /usr/local/fsl/bin/fslmaths "$@"
#
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#   File "/tmp/ipykernel_833046/56921799.py", line 106, in <module>
#     output_df.to_csv(output_file, index=False)
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/pandas/util/_decorators.py", line 333, in wrapper
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/pandas/core/generic.py", line 3967, in to_csv
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/pandas/io/formats/format.py", line 987, in to_csv
# ModuleNotFoundError: No module named 'pandas.io.formats.csvs'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/pygments/styles/__init__.py", line 45, in get_style_by_name
# ModuleNotFoundError: No module named 'pygments.styles.default'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 2168, in showtraceback
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1457, in structured_traceback
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1348, in structured_traceback
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1195, in structured_traceback
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1085, in format_exception_as_a_whole
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/IPython/core/ultratb.py", line 1136, in get_records
#   File "/hus/home/oliwin/.local/lib/python3.12/site-packages/pygments/styles/__init__.py", line 47, in get_style_by_name
# pygments.util.ClassNotFound: Could not find style module 'pygments.styles.default', though it should be builtin.

# %%
print(output_df)
# Out:
#    Patient Number  SN_L_mask_STAGE_CROWN_PD_MAP_reg_mni  \
# 0        0000D71C                            611.134328
# 1        0000D2D0                            682.961905
# 2        0000997A                            699.316239
# 3        00008904                            629.702703
# 4        00008289                            626.151685
# ..            ...                                   ...
# 62       00005018                            673.416309
# 63       00004943                            633.224670
# 64       000038BE                            655.110599
# 65       00004468                            607.886364
# 66       00002478                            629.067265
#
#     SN_L_mask_STAGE_CROWN_PD_MAPa_reg_mni  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 62                             673.416309
# 63                                    NaN
# 64                                    NaN
# 65                                    NaN
# 66                                    NaN
#
#     SN_L_mask_STAGE_CROWN_R2S_A2_reg_mni  SN_L_mask_STAGE_CROWN_R2S_reg_mni  \
# 0                            6991.944681                        6203.161702
# 1                             511.289362                         620.217021
# 2                            6925.085837                        6223.012766
# 3                            7409.148936                        5613.463830
# 4                            6656.670588                         510.893617
# ..                                   ...                                ...
# 62                           9191.447826                        5574.125000
# 63                           4996.465116                        4740.775862
# 64                            578.361702                        6239.442982
# 65                           7163.708920                        7075.004255
# 66                          15882.706383                        8640.346320
#
#     SN_L_mask_STAGE_CROWN_T2S_A2_reg_mni  SN_L_mask_STAGE_CROWN_T2S_reg_mni  \
# 0                            6350.280851                        5820.241379
# 1                            7449.144681                        8321.600000
# 2                            7186.795745                        6851.405172
# 3                            7665.953191                        8024.935897
# 4                            9692.906383                        7312.642553
# ..                                   ...                                ...
# 62                           6358.646766                        6724.048673
# 63                           5659.085106                        6603.176211
# 64                           6044.442857                        7181.157447
# 65                           5518.446809                        6328.627706
# 66                           6014.991379                        5626.255319
#
#     SN_L_mask_STAGE_CROWN_TRUE_PD_MAP_reg_mni  \
# 0                                  708.233945
# 1                                  687.772152
# 2                                  760.273504
# 3                                  719.809302
# 4                                  753.672414
# ..                                        ...
# 62                                 717.850467
# 63                                 759.166667
# 64                                 656.532051
# 65                                 749.095238
# 66                                 759.258621
#
#     SN_L_mask_STAGE_CROWN_TRUE_PD_MAPa_reg_mni  \
# 0                                   703.571429
# 1                                   773.900000
# 2                                   703.309091
# 3                                   775.660944
# 4                                   715.264706
# ..                                         ...
# 62                                  741.162162
# 63                                  757.855263
# 64                                  739.938967
# 65                                  743.092105
# 66                                  705.952941
#
#     SN_L_mask_STAGE_HPF_ECHO-3_e3_reg_mni  ...  SN_mask_STAGE_simGM_reg_mni  \
# 0                             2082.553191  ...                    71.384298
# 1                             2054.127660  ...                    70.450980
# 2                             2446.621277  ...                   101.813433
# 3                             2054.106383  ...                    70.057778
# 4                             2766.957447  ...                    83.518116
# ..                                    ...  ...                          ...
# 62                            2120.217021  ...                    92.713235
# 63                            2476.846809  ...                   115.957576
# 64                            2397.753191  ...                   127.742553
# 65                            2037.778723  ...                    83.971698
# 66                                    NaN  ...                          NaN
#
#     SN_mask_STAGE_simWM_reg_mni  SN_mask_STAGE_sim_GRE_reg_mni  \
# 0                    186.933486                     482.455319
# 1                    363.571142                     504.969636
# 2                    274.924406                     466.430493
# 3                    250.321429                     460.729730
# 4                    399.242485                     524.400000
# ..                          ...                            ...
# 62                   249.032389                     446.022670
# 63                   239.916290                     499.108108
# 64                   356.995833                     459.147186
# 65                   254.525000                     400.875622
# 66                          NaN                            NaN
#
#     SN_mask_STAGE_sim_GREa_reg_mni  SN_mask_STAGE_tSWI_ECHO-3_e3_reg_mni  \
# 0                       413.171171                            162.532075
# 1                       480.370690                            143.713178
# 2                       461.188119                            148.861224
# 3                       468.401070                            122.429293
# 4                       516.614919                            167.638298
# ..                             ...                                   ...
# 62                      463.850962                            155.519149
# 63                      567.714286                            153.509434
# 64                      504.202840                            150.484407
# 65                      454.284536                            146.870000
# 66                             NaN                                   NaN
#
#     SN_mask_STAGE_tSWI_mIP_ECHO-3_e3_reg_mni  \
# 0                                  92.002660
# 1                                 116.973843
# 2                                 121.966000
# 3                                  98.838298
# 4                                  97.569138
# ..                                       ...
# 62                                124.596000
# 63                                119.424000
# 64                                118.183206
# 65                                106.668103
# 66                                       NaN
#
#     SN_mask_STAGE_tSWIhpf_ECHO-3_e3_reg_mni  SN_mask_mprage_reg_mni  \
# 0                                171.629787              213.642857
# 1                                176.490566              183.416834
# 2                                107.941667               98.778000
# 3                                160.859574               95.200000
# 4                                151.310638              107.298000
# ..                                      ...                     ...
# 62                               146.115000              108.206000
# 63                               159.162791              189.000000
# 64                               138.046784              115.020000
# 65                               148.764192              111.620000
# 66                                      NaN              246.602000
#
#     SN_mask_mprage_reg_mni_betted  SN_mask_mprage_reg_mni_limiting
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
# ..                            ...                              ...
# 62                            NaN                              NaN
# 63                            NaN                              NaN
# 64                            NaN                              NaN
# 65                            NaN                              NaN
# 66                            NaN                              NaN
#
# [67 rows x 142 columns]

# %%
# saving the mean intensities that were extracted before server crash to csv
output_file = 'mri_data_sn.csv'  
output_df.to_csv(output_file, index=False)
print(f"Transformed CSV saved to {output_file}")
# Out:
# Transformed CSV saved to mri_data_sn.csv

# %% [markdown]
# The Linux server crashed during the first extraction. The participants that were missed were identified by cross-referencing the patient IDs from the CSV file containing WM intensities. The extraction was then performed for these missing participants.

# %%
# first round of extraction from SN cross referenced with WM extraction csv to find missing participants
sn_file = "mri_data_sn.csv"  
white_file = "mri_data_white.csv" 

sn_df = pd.read_csv(sn_file)
white_df = pd.read_csv(white_file)

# extracting 'Patient Number' column from both files
sn_patients = set(sn_df['Patient Number'])
white_patients = set(white_df['Patient Number'])

# identifying participants in WM csv file, but not in SN csv
missing_patients = white_patients - sn_patients

print("Missing patients:")
for patient in sorted(missing_patients):
    print(patient)
# Out:
# Missing patients:
# 00000EAE
# 000030C7
# 0000868E
# 000090DC
# 0000991B
# 0000AF0D
# 0000B5CD
# 0000C2A9
# 0000C65E
# 0000C788
# 0000CC09
# 0000CFCD
# 0000DAD2
# 0000DEB2

# %%
# define the list of missing participants
missing_patients = [
    "00000EAE", "000030C7", "0000868E", "000090DC", "0000991B", 
    "0000AF0D", "0000B5CD", "0000C2A9", "0000C65E", "0000C788", 
    "0000CC09", "0000CFCD", "0000DAD2", "0000DEB2", "00002478"
]


patients_data = {}

for root, dirs, files in os.walk(base_dir):
    if "FSL" in dirs:
        fsl_dir = os.path.join(root, "FSL")
        
        # extract participant number 
        patient_number = os.path.basename(root)

        # process only the specified missing participants
        if patient_number not in missing_patients:
            continue

        # loop through NIfTI files in the FSL directory
        for filename in os.listdir(fsl_dir):
            # process only files with "mni", "nii.gz"
            if (
                "mni" in filename
                and "mask" not in filename
                and "new" not in filename
                and "flirt" not in filename
                and "flirt_masked" not in filename
                and not filename.endswith(".mat")
                and filename.endswith(".nii.gz")
            ):
                input_file = os.path.join(fsl_dir, filename)

                print(f"Processing file: {input_file}")

                # loop through the SNpc masks (left, right and combined) - each MRI file is processed three times  
                for mask_file in [SN_mask, mask_sn_r, mask_sn_l]:
                    try:
                        # use FLIRT to perform the registration of SNpc masks
                        flirt_output = f"{input_file}_flirt_{os.path.basename(mask_file).split('.')[0]}"
                        flirt_matrix = f"{flirt_output}.mat"
                        flirt_command = f"flirt -in {input_file} -ref {mask_file} -out {flirt_output} -omat {flirt_matrix}"
                        process_flirt = subprocess.run(flirt_command, shell=True, capture_output=True, text=True)

                        if process_flirt.returncode != 0:
                            print(f"Error applying FLIRT to {filename} with mask {mask_file}: {process_flirt.stderr}")
                            continue  # continue with the next mask for same file

                        # use fslmaths to apply the masks and threshold negative values to zero
                        flirt_masked = f"{flirt_output}_masked"
                        fslmaths_command = f"fslmaths {flirt_output} -mas {mask_file} -thr 0 {flirt_masked}"
                        process_fslmaths = subprocess.run(fslmaths_command, shell=True, capture_output=True, text=True)

                        if process_fslmaths.returncode != 0:
                            print(f"Error applying fslmaths to {filename} with mask {mask_file}: {process_fslmaths.stderr}")
                            continue  # continue with the next mask for same file

                        # use fslstats to extract mean intensity within the region
                        stats_command = f"fslstats {flirt_masked} -M"  # -M for Mean Intensity 
                        process_stats = subprocess.run(stats_command, shell=True, capture_output=True, text=True)

                        if process_stats.returncode != 0:
                            print(f"Error processing {filename}: {process_stats.stderr}")
                            continue  # continue with the next mask for same file

                        
                        stats = process_stats.stdout.strip().split()
                        mean_intensity = float(stats[0])  

                        # remove intermediate files and temporary NIfTI outputs 
                        try:
                            for file_to_delete in [flirt_matrix, flirt_output + ".nii.gz", flirt_masked + ".nii.gz"]:
                                if os.path.exists(file_to_delete):
                                    os.remove(file_to_delete)
                                else:
                                    print(f"File not found: {file_to_delete}")
                        except OSError as e:
                            print(f"Error deleting files for {filename}: {e}")

                        # add data to the participant's entry
                        if patient_number not in patients_data:
                            patients_data[patient_number] = {}

                        mask_name = os.path.basename(mask_file).split('.')[0]  
                        filename_base = filename.replace('.nii.gz', '') 
                        mask_key = f'{mask_name}_{filename_base}'

                        patients_data[patient_number][mask_key] = mean_intensity

                    except Exception as e:
                        print(f"Error processing {filename} with mask {mask_file} for patient {patient_number}: {e}")
                        continue  # continue to next mask or next file

# preparing the dataframe to store mean intensities
header = ['Patient Number']
all_keys = set()
for intensities in patients_data.values():
    all_keys.update(intensities.keys())
header.extend(sorted(all_keys))  

output_data = []
for patient_number, intensities in patients_data.items():
    row = [patient_number]
    for col in header[1:]:
        row.append(intensities.get(col, None))  # use None for missing values
    output_data.append(row)

# creating the dataframe
output_df = pd.DataFrame(output_data, columns=header)

# saving the dataframe as csv file for further analysis
output_file = 'mri_data_sn_missing_patients.csv'
output_df.to_csv(output_file, index=False)
print(f"Transformed CSV saved to {output_file}")
# Out:
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00002478/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000991B/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000868E/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000090DC/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/000030C7/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CC09/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000CFCD/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000B5CD/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DAD2/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000DEB2/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C65E/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C788/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000AF0D/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/0000C2A9/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/mprage_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_KMAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_T1WE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_simCSF_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_simGM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_simWM_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Processing file: /hus/home/oliwin/data/study_name/00000EAE/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Transformed CSV saved to mri_data_sn_missing_patients.csv
