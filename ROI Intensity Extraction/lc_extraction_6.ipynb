# %% [markdown]
# <h1 style="text-align: center;"> LOCUS COERULEUS (LC) - MEAN INTENSITY EXTRACTION </h1>

# %% [markdown]
# This notebook continues extraction for participants missed during first extraction, due to server crash.

# %%
import os
import pandas as pd
import subprocess

# %%
#defining base directory and LC mask names
base_dir = "/hus/home/oliwin/data/study_name"

LC_mask = f"{base_dir}/LC_mask.nii.gz"
mask_lc_l = f"{base_dir}/LC_L_mask.nii.gz"
mask_lc_r = f"{base_dir}/LC_R_mask.nii.gz"

# %%
# 6th list of missing participants from first extraction
# this list contains 12 of the missing participants
missing_patients = ["0000EF8B", "0000EFFD", "0000F262", "0000F33F", "0000F612", 
 "0000F633", "0000F663", "0000F810", "0000F8F8", "0000F955", 
 "0000FA9A", "0000FEFA"]

# dictionary to store participant-wise data
patients_data = {}

# 6th list of missing participants
output_file = 'mri_data_LC_missing_patients_6.csv'

header = ['Patient Number']
all_keys = set()

# saving current results to csv file
def save_progress():
    global header

    all_keys.update(*(intensities.keys() for intensities in patients_data.values()))
    header = ['Patient Number'] + sorted(all_keys)

    output_data = []
    for patient_number, intensities in patients_data.items():
        row = [patient_number]
        for col in header[1:]:
            row.append(intensities.get(col, None))  # use None for missing values
        output_data.append(row)

    output_df = pd.DataFrame(output_data, columns=header)
    output_df.to_csv(output_file, index=False)
    print(f"Progress saved to {output_file}")

try:
    # loop through subdirectories 'FSL' in base_dir (recursively)
    for root, dirs, files in os.walk(base_dir):
        if "FSL" in dirs:
            fsl_dir = os.path.join(root, "FSL")
            
            # extracting participant number from folder name
            patient_number = os.path.basename(root)

            # processing only the specified missing participants
            if patient_number not in missing_patients:
                continue

            # loop through NIfTI files in the FSL directory
            for filename in os.listdir(fsl_dir):
                # process only files with "mni", "nii.gz"
                if (
                    "mni" in filename
                    and "mask" not in filename
                    and "new" not in filename
                    and "flirt" not in filename
                    and "flirt_masked" not in filename
                    and not filename.endswith(".mat")
                    and filename.endswith(".nii.gz")
                ):
                    input_file = os.path.join(fsl_dir, filename)

                    print(f"Processing file: {input_file}")

                    # loop through the LC masks (left, right, combined) - each MRI file is processed three times
                    for mask_file in [LC_mask, mask_lc_r, mask_lc_l]:
                        try:
                            # use FLIRT to perform registration of the LC masks
                            flirt_output = f"{input_file}_flirt_{os.path.basename(mask_file).split('.')[0]}"
                            flirt_matrix = f"{flirt_output}.mat"
                            flirt_command = f"flirt -in {input_file} -ref {mask_file} -out {flirt_output} -omat {flirt_matrix}"
                            process_flirt = subprocess.run(flirt_command, shell=True, capture_output=True, text=True)

                            if process_flirt.returncode != 0:
                                print(f"Error applying FLIRT to {filename} with mask {mask_file}: {process_flirt.stderr}")
                                continue  # continue with the next mask for same file

                            # use fslmaths to apply the masks and threshold negative values to zero
                            flirt_masked = f"{flirt_output}_masked"
                            fslmaths_command = f"fslmaths {flirt_output} -mas {mask_file} -thr 0 {flirt_masked}"
                            process_fslmaths = subprocess.run(fslmaths_command, shell=True, capture_output=True, text=True)

                            if process_fslmaths.returncode != 0:
                                print(f"Error applying fslmaths to {filename} with mask {mask_file}: {process_fslmaths.stderr}")
                                continue  # continue with the next mask for same file

                            # use fslstats to extract mean intensities within the region
                            stats_command = f"fslstats {flirt_masked} -M"  # -M for Mean Intensity 
                            process_stats = subprocess.run(stats_command, shell=True, capture_output=True, text=True)

                            if process_stats.returncode != 0:
                                print(f"Error processing {filename}: {process_stats.stderr}")
                                continue  # continue with the next mask for same file

                            
                            stats = process_stats.stdout.strip().split()
                            mean_intensity = float(stats[0])  

                            # remove intermediate files and temporary NIfTI outputs 
                            try:
                                for file_to_delete in [flirt_matrix, flirt_output + ".nii.gz", flirt_masked + ".nii.gz"]:
                                    if os.path.exists(file_to_delete):
                                        os.remove(file_to_delete)
                                    else:
                                        print(f"File not found: {file_to_delete}")
                            except OSError as e:
                                print(f"Error deleting files for {filename}: {e}")

                            # add the data to the participant's entry
                            if patient_number not in patients_data:
                                patients_data[patient_number] = {}

                            mask_name = os.path.basename(mask_file).split('.')[0]  
                            filename_base = filename.replace('.nii.gz', '') 
                            mask_key = f'{mask_name}_{filename_base}'

                            patients_data[patient_number][mask_key] = mean_intensity

                            # saving mean intensity immediately after each file is processed with all three masks
                            save_progress()

                        except Exception as e:
                            print(f"Error processing {filename} with mask {mask_file} for patient {patient_number}: {e}")
                            continue  # continue to the next mask or next file

    # final save after all participants and files have been processed
    print("Final saving progress...")
    save_progress()

# handle interruptions and unexpected errors
except KeyboardInterrupt:
    print("Process interrupted, saving progress...")
    save_progress()

except Exception as e:
    print(f"An error occurred: {e}")
    save_progress()
# Out:
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F33F/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FEFA/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F955/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F810/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F663/FSL/STAGE_simGM_reg_mni.nii.gz
# ...
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000F8F8/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/mprage_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_CROWN_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_CROWN_R2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_CROWN_R2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_CROWN_T2S_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_CROWN_T2S_A2_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_CROWN_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_CROWN_TRUE_PD_MAPa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_HPF_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_KMAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_MRA_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_R2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_R2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_SWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_SWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_T1MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_T1WE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_T2S_MIP_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_T2S_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_TRUE_PD_MAP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_dSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_dSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_meSWIM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_meSWIM_HPF__reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_meSWIM_HPF_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_meSWIM_filled_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_meSWIM_filled_MIP_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_mpSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_pSWIM_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_simCSF_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_simFLAIR_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_simGM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_simWM_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_sim_GRE_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_sim_GREa_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_tSWI_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_tSWI_mIP_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Processing file: /hus/home/oliwin/data/study_name/0000FA9A/FSL/STAGE_tSWIhpf_ECHO-3_e3_reg_mni.nii.gz
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Progress saved to mri_data_LC_missing_patients_6.csv
# Final saving progress...
# Progress saved to mri_data_LC_missing_patients_6.csv
